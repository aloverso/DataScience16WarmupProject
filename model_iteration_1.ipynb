# %%
import pandas as pd
titanic = pd.read_csv('train.csv')
titanic_test = pd.read_csv('test.csv')

# %% [markdown]
# This step imports the training and test sets

# %%
def clean_data(data, age_filler):
    data.Age = data.Age.fillna(age_filler)
    data.Fare = data.Fare.fillna(data.Fare.median())
    data.loc[data.Sex == "female", "Sex"] = 1
    data.loc[data.Sex == "male", "Sex"] = 0
    data.Embarked = data.Embarked.fillna("S")
    data.loc[data.Embarked == "S", "Embarked"] = 0
    data.loc[data.Embarked == "C", "Embarked"] = 1
    data.loc[data.Embarked == "Q", "Embarked"] = 2
    return data
    
titanic = clean_data(titanic, titanic.Age.median())
titanic_test = clean_data(titanic_test, titanic.Age.median())
print "cleaned"
# Out:
# cleaned

# %% [markdown]
# This step defines a function called clean_data that I can use to clean both the train and test sets in the same way.  Because we need to replace the age variable with the same median in the train and test sets, it takes that age as an argument.  Overall, it just removed the NaN values in relevant columns and replaces string values with numbers instead

# %%
from sklearn import cross_validation
from sklearn.linear_model import LogisticRegression

predictors = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]

alg = LogisticRegression(random_state=1)
# Compute the accuracy score for all the cross validation folds.  (much simpler than what we did before!)
scores = cross_validation.cross_val_score(alg, titanic[predictors], titanic["Survived"], cv=3)
# Take the mean of the scores (because we have one for each fold)
print(scores.mean())
# Out:
# 0.787878787879

# %% [markdown]
# This step imports scikit-learn and uses it to build a logistic regression model.  We create an algorithm, and cross-validate it on our training set to get an idea of what the scores might be.  It creates 3-fold data, as opposed to the in-class example where instead we used half the data for training and half for evaluating.

# %%
# Train the algorithm using all the training data
alg.fit(titanic[predictors], titanic["Survived"])

# Make predictions using the test set.
predictions = alg.predict(titanic_test[predictors])

# Create a new dataframe with only the columns Kaggle wants from the dataset.
submission = pd.DataFrame({
        "PassengerId": titanic_test["PassengerId"],
        "Survived": predictions
    })

submission.to_csv("kaggle.csv", index=False)

# %% [markdown]
# This step fits our logistic regression algoritm to the training set using the relevant columns from the training set (we ignore the name, cabin, etc, as defined in the predictors array), and match it to the Survived column as the thing we want to predict.  Then, we use this algorithm we trained to create predictions from the test set, and turn those predictions into a csv to submit to kaggle

# %% [markdown]
# Kaggle submission score: 75.120

# %% [markdown]
# I think one place to start with improving the DataQuest model is based on what we talked about in class on Tuesday 1/26.  We discussed how assigning numbers to string values can skew the model because it's creating an artificial range for that variable.  In this model, we turned the Embarked variable into either 0, 1 or 2.  I think one way to see if it can do better is to create three new columns for something like "EmbarkedC", "EmbarkedS", and "EmbarkedQ" and have a true/false boolean value for each, so that we can separate the effects.

# %%
def parse_port(port):
    if port == 0: # port is s=0, c=1, q=2
        return 1,0,0
    elif port == 1:
        return 0,1,0
    elif port == 2:
        return 0,0,1

def make_embarked_cols(data):
    s = []
    c = []
    q = []

    for port in data.Embarked:
        sbool, cbool, qbool = parse_port(port)
        s.append(sbool)
        c.append(cbool)
        q.append(qbool)

    data['EmbarkedS'] = s
    data['EmbarkedC'] = c
    data['EmbarkedQ'] = q
    
    return data

make_embarked_cols(titanic)
make_embarked_cols(titanic_test)
print titanic.EmbarkedS
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
# 6      1
# 7      1
# 8      1
# 9      0
# 10     1
# 11     1
# 12     1
# 13     1
# 14     1
# 15     1
# 16     0
# 17     1
# 18     1
# 19     0
# 20     1
# 21     1
# 22     0
# 23     1
# 24     1
# 25     1
# 26     0
# 27     1
# 28     0
# 29     1
#       ..
# 861    1
# 862    1
# 863    1
# 864    1
# 865    1
# 866    0
# 867    1
# 868    1
# 869    1
# 870    1
# 871    1
# 872    1
# 873    1
# 874    0
# 875    0
# 876    1
# 877    1
# 878    1
# 879    0
# 880    1
# 881    1
# 882    1
# 883    1
# 884    1
# 885    0
# 886    1
# 887    1
# 888    1
# 889    0
# 890    0
# Name: EmbarkedS, dtype: int64

# %% [markdown]
# These two functions sort through the Embarked column and creates 3 new columns in the dataset

# %%
predictors = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "EmbarkedS", "EmbarkedQ", "EmbarkedC"]

alg = LogisticRegression(random_state=1)
# Compute the accuracy score for all the cross validation folds.  (much simpler than what we did before!)
scores = cross_validation.cross_val_score(alg, titanic[predictors], titanic["Survived"], cv=3)
# Take the mean of the scores (because we have one for each fold)
print(scores.mean())
# Out:
# 0.789001122334

# %%
# Train the algorithm using all the training data
alg.fit(titanic[predictors], titanic["Survived"])

# Make predictions using the test set.
predictions = alg.predict(titanic_test[predictors])

# Create a new dataframe with only the columns Kaggle wants from the dataset.
submission = pd.DataFrame({
        "PassengerId": titanic_test["PassengerId"],
        "Survived": predictions
    })

submission.to_csv("kaggle2.csv", index=False)

# %% [markdown]
# Despite the _slightly_ better score in the cross-validation, my new Kaggle submission actually scored more poorly, at a score of 0.74641. :(  Clearly, the issue with the Embarked ports is not as important as I though, or the port of embarkation doesn't even actually matter that much

# %%
# let's take a look at the ones it predicted wrong

newpredictions = alg.predict(titanic[predictors])

predictedDead_isAlive = 0
predictedAlive_isDead = 0

for i in range(len(newpredictions)):
    if titanic.Survived[i] != newpredictions[i]:
        print titanic[predictors].loc[i]
        print "SURVIVED: ", titanic.Survived.loc[i]
        print "PREDICTED: ", newpredictions[i]
        predictedDead_isAlive += titanic.Survived.loc[i]
        predictedAlive_isDead += newpredictions[i]
        
print "predictedDead_isAlive:",predictedDead_isAlive
print "predictedAlive_isDead:",predictedAlive_isDead
# Out:
# Pclass            3
# Sex               1
# Age              14
# SibSp             0
# Parch             0
# Fare         7.8542
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 14, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        2
# Sex           0
# Age          28
# SibSp         0
# Parch         0
# Fare         13
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 17, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        3
# Sex           1
# Age          31
# SibSp         1
# Parch         0
# Fare         18
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 18, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        2
# Sex           0
# Age          34
# SibSp         0
# Parch         0
# Fare         13
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 21, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            28
# SibSp           0
# Parch           0
# Fare         35.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 23, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               1
# Age               8
# SibSp             3
# Parch             1
# Fare         21.075
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 24, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                1
# Age               38
# SibSp              1
# Parch              5
# Fare         31.3875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 25, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               28
# SibSp              1
# Parch              0
# Fare         82.1708
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 34, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               0
# Age              28
# SibSp             0
# Parch             0
# Fare         7.2292
# EmbarkedS         0
# EmbarkedQ         0
# EmbarkedC         1
# Name: 36, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        3
# Sex           1
# Age          18
# SibSp         2
# Parch         0
# Fare         18
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 38, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        2
# Sex           1
# Age          27
# SibSp         1
# Parch         0
# Fare         21
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 41, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             1
# Age            18
# SibSp           1
# Parch           0
# Fare         17.8
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 49, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          1
# Sex             0
# Age            28
# SibSp           0
# Parch           0
# Fare         35.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 55, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         27.7208
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 64, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                0
# Age               28
# SibSp              1
# Parch              1
# Fare         15.2458
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 65, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              1
# Age             17
# SibSp            4
# Parch            2
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 68, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                0
# Age               32
# SibSp              0
# Parch              0
# Fare         56.4958
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 74, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          2
# Sex             0
# Age          0.83
# SibSp           0
# Parch           2
# Fare           29
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 78, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass         3
# Sex            0
# Age           29
# SibSp          0
# Parch          0
# Fare         9.5
# EmbarkedS      1
# EmbarkedQ      0
# EmbarkedC      0
# Name: 81, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              1
# Age             33
# SibSp            3
# Parch            0
# Fare         15.85
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 85, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               1
# Age              28
# SibSp             0
# Parch             0
# Fare         7.8958
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 100, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               21
# SibSp              0
# Parch              1
# Fare         77.2875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 102, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              0
# Age             28
# SibSp            0
# Parch            0
# Fare         7.775
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 107, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age             14.5
# SibSp              1
# Parch              0
# Fare         14.4542
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 111, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              1
# Age             20
# SibSp            1
# Parch            0
# Fare         9.825
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 113, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                1
# Age               17
# SibSp              0
# Parch              0
# Fare         14.4583
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 114, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               24
# SibSp              0
# Parch              1
# Fare         247.521
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 118, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age               2
# SibSp             4
# Parch             2
# Fare         31.275
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 119, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                0
# Age               12
# SibSp              1
# Parch              0
# Fare         11.2417
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 125, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               0
# Age              24
# SibSp             0
# Parch             0
# Fare         7.1417
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 127, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            24
# SibSp           0
# Parch           0
# Fare         79.2
# EmbarkedS       0
# EmbarkedQ       0
# EmbarkedC       1
# Name: 139, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                1
# Age               28
# SibSp              0
# Parch              2
# Fare         15.2458
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 140, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               0
# Age              27
# SibSp             0
# Parch             0
# Fare         7.7958
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 146, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               1
# Age               9
# SibSp             2
# Parch             2
# Fare         34.375
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 147, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               0
# Age               9
# SibSp             0
# Parch             2
# Fare         20.525
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 165, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                1
# Age               50
# SibSp              0
# Parch              0
# Fare         28.7125
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 177, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        2
# Sex           0
# Age           1
# SibSp         2
# Parch         1
# Fare         39
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 183, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           1
# Sex              0
# Age             45
# SibSp            0
# Parch            0
# Fare         26.55
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 187, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        2
# Sex           0
# Age           3
# SibSp         1
# Parch         1
# Fare         26
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 193, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        2
# Sex           1
# Age          24
# SibSp         0
# Parch         0
# Fare         13
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 199, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             0
# Age            18
# SibSp           0
# Parch           0
# Fare         8.05
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 204, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age                2
# SibSp              0
# Parch              1
# Fare         10.4625
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 205, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                0
# Age               26
# SibSp              0
# Parch              0
# Fare         18.7875
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 207, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        1
# Sex           0
# Age          40
# SibSp         0
# Parch         0
# Fare         31
# EmbarkedS     0
# EmbarkedQ     0
# EmbarkedC     1
# Name: 209, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             0
# Age            16
# SibSp           0
# Parch           0
# Fare         8.05
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 220, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        1
# Sex           0
# Age          38
# SibSp         1
# Parch         0
# Fare         90
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 224, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          2
# Sex             0
# Age            19
# SibSp           0
# Parch           0
# Fare         10.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 226, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age                5
# SibSp              4
# Parch              2
# Fare         31.3875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 233, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            28
# SibSp           0
# Parch           0
# Fare         7.55
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 235, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                1
# Age               28
# SibSp              1
# Parch              0
# Fare         14.4542
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 240, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              1
# Age             25
# SibSp            0
# Parch            0
# Fare         7.775
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 246, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               37
# SibSp              1
# Parch              1
# Fare         52.5542
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 248, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age               29
# SibSp              1
# Parch              1
# Fare         10.4625
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 251, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                0
# Age                3
# SibSp              4
# Parch              2
# Fare         31.3875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 261, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            28
# SibSp           0
# Parch           0
# Fare         7.75
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 264, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              0
# Age             25
# SibSp            1
# Parch            0
# Fare         7.775
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 267, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        3
# Sex           0
# Age          25
# SibSp         0
# Parch         0
# Fare          0
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 271, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              1
# Age             35
# SibSp            1
# Parch            1
# Fare         20.25
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 279, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             0
# Age            19
# SibSp           0
# Parch           0
# Fare         8.05
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 283, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass         3
# Sex            0
# Age           30
# SibSp          0
# Parch          0
# Fare         9.5
# EmbarkedS      1
# EmbarkedQ      0
# EmbarkedC      0
# Name: 286, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        2
# Sex           0
# Age          42
# SibSp         0
# Parch         0
# Fare         13
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 288, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            24
# SibSp           0
# Parch           0
# Fare         8.85
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 293, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         27.7208
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 295, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            1
# Sex               1
# Age               2
# SibSp             1
# Parch             2
# Fare         151.55
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 297, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          1
# Sex             0
# Age            28
# SibSp           0
# Parch           0
# Fare         30.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 298, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              0
# Age             28
# SibSp            2
# Parch            0
# Fare         23.25
# EmbarkedS        0
# EmbarkedQ        1
# EmbarkedC        0
# Name: 301, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        2
# Sex           1
# Age          26
# SibSp         1
# Parch         1
# Fare         26
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 312, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age              31
# SibSp             1
# Parch             1
# Fare         20.525
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 328, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             0
# Age            45
# SibSp           0
# Parch           0
# Fare         8.05
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 338, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        2
# Sex           0
# Age           2
# SibSp         1
# Parch         1
# Fare         26
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 340, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             0
# Age             3
# SibSp           1
# Parch           1
# Fare         15.9
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 348, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        2
# Sex           1
# Age          38
# SibSp         0
# Parch         0
# Fare         13
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 357, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                1
# Age               45
# SibSp              0
# Parch              1
# Fare         14.4542
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 362, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               22
# SibSp              0
# Parch              0
# Fare         135.633
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 373, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age               3
# SibSp             3
# Parch             1
# Fare         21.075
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 374, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           1
# Sex              0
# Age             27
# SibSp            0
# Parch            2
# Fare         211.5
# EmbarkedS        0
# EmbarkedQ        0
# EmbarkedC        1
# Name: 377, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass         1
# Sex            0
# Age           36
# SibSp          1
# Parch          2
# Fare         120
# EmbarkedS      1
# EmbarkedQ      0
# EmbarkedC      0
# Name: 390, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               0
# Age              21
# SibSp             0
# Parch             0
# Fare         7.7958
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 391, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               1
# Age              31
# SibSp             0
# Parch             0
# Fare         7.8542
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 396, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              0
# Age             39
# SibSp            0
# Parch            0
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 400, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              1
# Age             21
# SibSp            1
# Parch            0
# Fare         9.825
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 402, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age              20
# SibSp             0
# Parch             0
# Fare         8.6625
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 404, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           2
# Sex              0
# Age              3
# SibSp            1
# Parch            1
# Fare         18.75
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 407, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              0
# Age             44
# SibSp            0
# Parch            0
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 414, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            28
# SibSp           0
# Parch           0
# Fare         8.05
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 415, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              1
# Age             10
# SibSp            0
# Parch            2
# Fare         24.15
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 419, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             1
# Age            28
# SibSp           1
# Parch           1
# Fare         14.4
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 423, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             0
# Age            32
# SibSp           0
# Parch           0
# Fare         8.05
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 429, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           1
# Sex              0
# Age             28
# SibSp            0
# Parch            0
# Fare         26.55
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 430, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               0
# Age              28
# SibSp             0
# Parch             0
# Fare         8.1125
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 444, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           1
# Sex              0
# Age             34
# SibSp            0
# Parch            0
# Fare         26.55
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 447, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            52
# SibSp           0
# Parch           0
# Fare         30.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 449, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           1
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Fare         27.75
# EmbarkedS        0
# EmbarkedQ        0
# EmbarkedC        1
# Name: 452, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               49
# SibSp              1
# Parch              0
# Fare         89.1042
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 453, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               0
# Age              29
# SibSp             0
# Parch             0
# Fare         7.8958
# EmbarkedS         0
# EmbarkedQ         0
# EmbarkedC         1
# Name: 455, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           1
# Sex              0
# Age             48
# SibSp            0
# Parch            0
# Fare         26.55
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 460, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               1
# Age              22
# SibSp             0
# Parch             0
# Fare         9.8375
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 474, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age              63
# SibSp             0
# Parch             0
# Fare         9.5875
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 483, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             0
# Age             9
# SibSp           1
# Parch           1
# Fare         15.9
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 489, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            1
# Sex               1
# Age              25
# SibSp             1
# Parch             2
# Fare         151.55
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 498, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             1
# Age            21
# SibSp           0
# Parch           0
# Fare         7.75
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 501, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age              28
# SibSp             0
# Parch             0
# Fare         7.6292
# EmbarkedS         0
# EmbarkedQ         1
# EmbarkedC         0
# Name: 502, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age              37
# SibSp             0
# Parch             0
# Fare         9.5875
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 503, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           1
# Sex              0
# Age             18
# SibSp            1
# Parch            0
# Fare         108.9
# EmbarkedS        0
# EmbarkedQ        0
# EmbarkedC        1
# Name: 505, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           1
# Sex              0
# Age             28
# SibSp            0
# Parch            0
# Fare         26.55
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 507, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                0
# Age               26
# SibSp              0
# Parch              0
# Fare         56.4958
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 509, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             0
# Age            29
# SibSp           0
# Parch           0
# Fare         7.75
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 510, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               36
# SibSp              0
# Parch              0
# Fare         26.2875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 512, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         221.779
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 527, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age              30
# SibSp             0
# Parch             0
# Fare         8.6625
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 534, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        2
# Sex           0
# Age          32
# SibSp         1
# Parch         0
# Fare         26
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 543, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             2
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         13.8625
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 547, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           2
# Sex              0
# Age              8
# SibSp            1
# Parch            1
# Fare         36.75
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 549, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              0
# Age             22
# SibSp            0
# Parch            0
# Fare         7.225
# EmbarkedS        0
# EmbarkedQ        0
# EmbarkedC        1
# Name: 553, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         227.525
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 557, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             1
# Age            36
# SibSp           1
# Parch           0
# Fare         17.4
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 559, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            28
# SibSp           0
# Parch           0
# Fare         8.05
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 564, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               1
# Age              29
# SibSp             0
# Parch             4
# Fare         21.075
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 567, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               0
# Age              32
# SibSp             0
# Parch             0
# Fare         7.8542
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 569, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          2
# Sex             0
# Age            62
# SibSp           0
# Parch           0
# Fare         10.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 570, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               36
# SibSp              0
# Parch              0
# Fare         26.3875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 572, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age               28
# SibSp              1
# Parch              0
# Fare         14.4583
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 578, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              0
# Age             32
# SibSp            0
# Parch            0
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 579, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            60
# SibSp           1
# Parch           1
# Fare         79.2
# EmbarkedS       0
# EmbarkedQ       0
# EmbarkedC       1
# Name: 587, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            28
# SibSp           0
# Parch           2
# Fare         7.75
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 593, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               49
# SibSp              1
# Parch              0
# Fare         56.9292
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 599, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           1
# Sex              0
# Age             35
# SibSp            0
# Parch            0
# Fare         26.55
# EmbarkedS        0
# EmbarkedQ        0
# EmbarkedC        1
# Name: 604, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            27
# SibSp           0
# Parch           0
# Fare         30.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 607, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            26
# SibSp           1
# Parch           0
# Fare         16.1
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 617, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               42
# SibSp              1
# Parch              0
# Fare         52.5542
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 621, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                0
# Age               20
# SibSp              1
# Parch              1
# Fare         15.7417
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 622, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        1
# Sex           0
# Age          80
# SibSp         0
# Parch         0
# Fare         30
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 630, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age             9
# SibSp           3
# Parch           2
# Fare         27.9
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 634, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             1
# Age             2
# SibSp           3
# Parch           2
# Fare         27.9
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 642, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             3
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         56.4958
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 643, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               48
# SibSp              1
# Parch              0
# Fare         76.7292
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 645, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            56
# SibSp           0
# Parch           0
# Fare         35.5
# EmbarkedS       0
# EmbarkedQ       0
# EmbarkedC       1
# Name: 647, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             1
# Age            18
# SibSp           0
# Parch           0
# Fare         6.75
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 654, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             1
# Age            32
# SibSp           1
# Parch           1
# Fare         15.5
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 657, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            1
# Sex               0
# Age              50
# SibSp             2
# Parch             0
# Fare         133.65
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 660, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              0
# Age             20
# SibSp            1
# Parch            0
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 664, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        2
# Sex           0
# Age          31
# SibSp         0
# Parch         0
# Fare         13
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 673, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               1
# Age              28
# SibSp             0
# Parch             0
# Fare         8.1375
# EmbarkedS         0
# EmbarkedQ         1
# EmbarkedC         0
# Name: 680, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        1
# Sex           0
# Age          31
# SibSp         1
# Parch         0
# Fare         57
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 690, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         56.4958
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 692, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               35
# SibSp              0
# Parch              0
# Fare         26.2875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 701, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age               18
# SibSp              0
# Parch              1
# Fare         14.4542
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 702, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass             1
# Sex                0
# Age               42
# SibSp              0
# Parch              0
# Fare         26.2875
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 707, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                0
# Age               28
# SibSp              1
# Parch              1
# Fare         15.2458
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 709, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass        1
# Sex           0
# Age          48
# SibSp         1
# Parch         0
# Fare         52
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 712, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            27
# SibSp           1
# Parch           0
# Fare         53.1
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 724, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              1
# Age             25
# SibSp            1
# Parch            0
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 729, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        1
# Sex           0
# Age          28
# SibSp         0
# Parch         0
# Fare         30
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 740, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              0
# Age             31
# SibSp            0
# Parch            0
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 744, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               0
# Age               6
# SibSp             0
# Parch             1
# Fare         12.475
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 751, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          2
# Sex             0
# Age          0.67
# SibSp           1
# Parch           1
# Fare         14.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 755, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass            3
# Sex               0
# Age              20
# SibSp             0
# Parch             0
# Fare         7.2292
# EmbarkedS         0
# EmbarkedQ         0
# EmbarkedC         1
# Name: 762, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          1
# Sex             0
# Age            28
# SibSp           0
# Parch           0
# Fare         39.6
# EmbarkedS       0
# EmbarkedQ       0
# EmbarkedC       1
# Name: 766, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          3
# Sex             1
# Age          30.5
# SibSp           0
# Parch           0
# Fare         7.75
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 767, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass          2
# Sex             1
# Age            57
# SibSp           0
# Parch           0
# Fare         10.5
# EmbarkedS       1
# EmbarkedQ       0
# EmbarkedC       0
# Name: 772, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               0
# Age               1
# SibSp             1
# Parch             2
# Fare         20.575
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 788, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             1
# Sex                0
# Age               28
# SibSp              0
# Parch              0
# Fare         30.6958
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 793, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              1
# Age             30
# SibSp            1
# Parch            1
# Fare         24.15
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 799, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               0
# Age            0.42
# SibSp             0
# Parch             1
# Fare         8.5167
# EmbarkedS         0
# EmbarkedQ         0
# EmbarkedC         1
# Name: 803, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              0
# Age             27
# SibSp            0
# Parch            0
# Fare         6.975
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 804, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           3
# Sex              1
# Age             18
# SibSp            0
# Parch            0
# Fare         7.775
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 807, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              1
# Age             23
# SibSp            0
# Parch            0
# Fare         7.925
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 816, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass            3
# Sex               0
# Age              27
# SibSp             0
# Parch             0
# Fare         8.6625
# EmbarkedS         1
# EmbarkedQ         0
# EmbarkedC         0
# Name: 821, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass          3
# Sex             0
# Age            28
# SibSp           0
# Parch           0
# Fare         7.75
# EmbarkedS       0
# EmbarkedQ       1
# EmbarkedC       0
# Name: 828, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass           2
# Sex              0
# Age           0.83
# SibSp            1
# Parch            1
# Fare         18.75
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 831, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                0
# Age               32
# SibSp              0
# Parch              0
# Fare         56.4958
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 838, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age                9
# SibSp              1
# Parch              1
# Fare         15.2458
# EmbarkedS          0
# EmbarkedQ          0
# EmbarkedC          1
# Name: 852, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass        2
# Sex           1
# Age          44
# SibSp         1
# Parch         0
# Fare         26
# EmbarkedS     1
# EmbarkedQ     0
# EmbarkedC     0
# Name: 854, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           1
# Sex              0
# Age             51
# SibSp            0
# Parch            0
# Fare         26.55
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 857, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                0
# Age                4
# SibSp              1
# Parch              1
# Fare         11.1333
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 869, dtype: object
# SURVIVED:  1
# PREDICTED:  0
# Pclass             3
# Sex                1
# Age               22
# SibSp              0
# Parch              0
# Fare         10.5167
# EmbarkedS          1
# EmbarkedQ          0
# EmbarkedC          0
# Name: 882, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# Pclass           3
# Sex              1
# Age             28
# SibSp            1
# Parch            2
# Fare         23.45
# EmbarkedS        1
# EmbarkedQ        0
# EmbarkedC        0
# Name: 888, dtype: object
# SURVIVED:  0
# PREDICTED:  1
# predictedDead_isAlive: 103
# predictedAlive_isDead: 74

# %% [markdown]
# It's interesting that my model predicted more dead people than there should be, but I'm not entirely sure how to edit the model to improve my secore based on this information

# %% [markdown]
# I know that from my exploration, it seemed to make a pretty big difference in survival rates on whether the subject was an adult or child.  I wonder if making this a specific column separate from age might change my results?

# %%
titanic['Child'] = titanic.Age <= 18
titanic_test['Child'] = titanic_test.Age <= 18
print titanic.Child
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9       True
# 10      True
# 11     False
# 12     False
# 13     False
# 14      True
# 15     False
# 16      True
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869     True
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875     True
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Child, dtype: bool

# %%
predictors = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "EmbarkedS", "EmbarkedQ", "EmbarkedC", "Child"]

alg = LogisticRegression(random_state=1)
# Compute the accuracy score for all the cross validation folds.  (much simpler than what we did before!)
scores = cross_validation.cross_val_score(alg, titanic[predictors], titanic["Survived"], cv=3)
# Take the mean of the scores (because we have one for each fold)
print(scores.mean())
# Out:
# 0.789001122334

# %%
for i in range(2,100):
    scores = cross_validation.cross_val_score(alg, titanic[predictors], titanic["Survived"], cv=i)
    # Take the mean of the scores (because we have one for each fold)
    print i, scores.mean()
# Out:
# 2 0.772187232327
# 3 0.789001122334
# 4 0.796850787567
# 5 0.795773475089
# 6 0.797985065603
# 7 0.798014645491
# 8 0.800286467474
# 9 0.796857463524
# 10 0.799171773919
# 11 0.80366948619
# 12 0.802582376897
# 13 0.803704224165
# 14 0.803654827316
# 15 0.801449444769
# 16 0.802594554568
# 17 0.79920142545
# 18 0.801337868481
# 19 0.800331077462
# 20 0.800231664471
# 21 0.798176352994
# 22 0.800268633805
# 23 0.801711410407
# 24 0.800501159054
# 25 0.800468720822
# 26 0.802578467284
# 27 0.798198488149
# 28 0.801497477657
# 29 0.801685141856
# 30 0.798050920776
# 31 0.801430160496
# 32 0.80273900748
# 33 0.802731219398
# 34 0.800324403266
# 35 0.800626373626
# 36 0.800381054131
# 37 0.800487661575
# 38 0.801344393593
# 39 0.803933988717
# 40 0.802879728967
# 41 0.80261714249
# 42 0.802709885008
# 43 0.801736900391
# 44 0.801711665527
# 45 0.800478975216
# 46 0.799383422324
# 47 0.801810377006
# 48 0.802643762183
# 49 0.803781161587
# 50 0.801683006536
# 51 0.80328078944
# 52 0.802758924082
# 53 0.801632445431
# 54 0.802892762043
# 55 0.802923351159
# 56 0.80175070028
# 57 0.802704678363
# 58 0.801662561576
# 59 0.800918079096
# 60 0.803174603175
# 61 0.8006245121
# 62 0.802103273071
# 63 0.803162974592
# 64 0.799519230769
# 65 0.801831501832
# 66 0.800671550672
# 67 0.800481110929
# 68 0.800193923723
# 69 0.80206749772
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-45d4f98c6687> in <module>()
#       1 for i in range(2,100):
# ----> 2     scores = cross_validation.cross_val_score(alg, titanic[predictors], titanic["Survived"], cv=i)
#       3     # Take the mean of the scores (because we have one for each fold)
#       4     print i, scores.mean()
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1431                                               train, test, verbose, None,
#    1432                                               fit_params)
# -> 1433                       for train, test in cv)
#    1434     return np.array(scores)[:, 0]
#    1435
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     802             self._iterating = True
#     803
# --> 804             while self.dispatch_one_batch(iterator):
#     805                 pass
#     806
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     660                 return False
#     661             else:
# --> 662                 self._dispatch(tasks)
#     663                 return True
#     664
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     568
#     569         if self._pool is None:
# --> 570             job = ImmediateComputeBatch(batch)
#     571             self._jobs.append(job)
#     572             self.n_dispatched_batches += 1
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, batch)
#     181         # Don't delay the application, to avoid keeping the input
#     182         # arguments in memory
# --> 183         self.results = batch()
#     184
#     185     def get(self):
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1522     start_time = time.time()
#    1523
# -> 1524     X_train, y_train = _safe_split(estimator, X, y, train)
#    1525     X_test, y_test = _safe_split(estimator, X, y, test, train)
#    1526
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _safe_split(estimator, X, y, indices, train_indices)
#    1592
#    1593     if y is not None:
# -> 1594         y_subset = safe_indexing(y, indices)
#    1595     else:
#    1596         y_subset = None
#
# /home/anne/anaconda2/lib/python2.7/site-packages/sklearn/utils/__init__.pyc in safe_indexing(X, indices)
#     150         # Pandas Dataframes and Series
#     151         try:
# --> 152             return X.iloc[indices]
#     153         except ValueError:
#     154             # Cython typed memoryviews internally used in pandas do not support
#
# /home/anne/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1225             return self._getitem_tuple(key)
#    1226         else:
# -> 1227             return self._getitem_axis(key, axis=0)
#    1228
#    1229     def _getitem_axis(self, key, axis=0):
#
# /home/anne/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1505
#    1506                 # force an actual list
# -> 1507                 key = list(key)
#    1508
#    1509             else:
#
# KeyboardInterrupt:

# %%
# Train the algorithm using all the training data
alg.fit(titanic[predictors], titanic["Survived"])

# Make predictions using the test set.
predictions = alg.predict(titanic_test[predictors])

# Create a new dataframe with only the columns Kaggle wants from the dataset.
submission = pd.DataFrame({
        "PassengerId": titanic_test["PassengerId"],
        "Survived": predictions
    })

submission.to_csv("kaggle6.csv", index=False)

# %% [markdown]
# Good news, this improved my model up to 0.76077!  Not very much of an increase though, but still, it's something.  I moved up 190 positions on the leaderboard!
